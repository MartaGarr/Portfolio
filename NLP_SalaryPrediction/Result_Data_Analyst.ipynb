# %% [markdown]
# # Web Scraping from Indeed.com & Predicting Salaries
#
# Houra Marta Taghavi, TX
#
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary classifier.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use a random forest regressor, as well as another classifier of your choice; either logistic regression, SVM, or KNN.
#
# * **Question**: Why would we want this to be a classification problem?
# * **Answer**: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.
#
# ### Scraping job listings from Indeed.com
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# I scarapped data analyst jobs for Washington, New York, and San Francisco with the salary of 60K,70K, 75K, 85K, and 100K. the salary and cities can be modified by changing the "cities_states" and "Analyst_salary_range" lists.

# %%
# importing libraries
import pandas as pd
from urllib.request import urlopen
import urllib.parse
from bs4 import BeautifulSoup

# %%
#defining cities, state and salary range
cities_states = ['Washington, DC','New York, NY', 'San Francisco, CA']
Analyst_salary_range = ['60', '70', '75', '85', '100']
levels = ['entry', 'mid', 'senior']

# %%
url_list = []

for city_state in cities_states:
    city = city_state.split(', ')[0].replace(' ','+')
    state = city_state.split(', ')[1]
    for salary in Analyst_salary_range:
        for level in levels:
            my_url = 'https://www.indeed.com/jobs?q=data+analyst+$'+salary+',000&l='+city+',+'+state+'&radius=50&explvl='+level+'_level&limit=100'
            url_list.append(my_url)

# %%
result_data_analyst = pd.DataFrame(columns=["Company","Location","Title","Salary","Level"])          
for url in url_list:
    page_open = urlopen(url)
    page_html = page_open.read()
    page_open.close()
    html = BeautifulSoup(page_html,"html.parser")
    analyst_jobs1 = pd.DataFrame(columns=["Company"])
    analyst_jobs2 = pd.DataFrame(columns=["Title"])
    analyst_jobs3 = pd.DataFrame(columns=["Location","Salary","Level"])
    
    for company in html.findAll("span",{"class":"company"}):
        company_name = company.text
        analyst_jobs1.loc[len(analyst_jobs1)] = [company_name]
        
    for titles in html.findAll('a', {'data-tn-element':'jobTitle'}):
        title = titles.text 
        analyst_jobs2.loc[len(analyst_jobs2)] = [title]

    for location in html.findAll("span",{"class":"location"}):
        location_name = location.text
        parsed = urllib.parse.urlsplit(url)
        info = parsed.query
        info =info.rpartition('analyst+$')[2]
        salary =info.replace('+$','').split('&l=',1)[0].replace(',','')
        level = info.split('explvl=',1)[1].split('&',1)[0]
        analyst_jobs3.loc[len(analyst_jobs3)] =[location_name,salary,level] 
       

        
     
    analyst_jobs1 = analyst_jobs1["Company"].str.replace("\n","")
    analyst_jobs2 = analyst_jobs2["Title"].str.replace("\n","")
    analyst_jobs3 ["Location"]= analyst_jobs3["Location"].str.replace("\n","")
    
    #merging all the information into a final dataframe
    result = pd.concat([analyst_jobs1, analyst_jobs2, analyst_jobs3], axis=1)
    result_data_analyst = pd.concat([result_data_analyst,result], axis=0)
# Out:
# C:\Users\shpir\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
result_data_analyst.shape
# Out:
# (2515, 5)

# %%
result_data_analyst
# Out:
#                                               Company         Level  \
# 0                          The HSC Health Care System   entry_level
# 1                                       Addison Group   entry_level
# 2                                               PCAOB   entry_level
# 3                                                 NSD   entry_level
# 4                                          Guidehouse   entry_level
# 5                                  ShadowObjects, LLC   entry_level
# 6             National Geospatial-Intelligence Agency   entry_level
# 7                                   9th Way Solutions   entry_level
# 8                                            Deloitte   entry_level
# 9              Government of the District of Columbia   entry_level
# 10                                               Uber   entry_level
# 11             Government of the District of Columbia   entry_level
# 12            General Dynamics Information Technology   entry_level
# 13          US Department of Health And Human Serv...   entry_level
# 14                                         Data Trust   entry_level
# 15                                         Guidehouse   entry_level
# 16                         The Counterterrorism Group   entry_level
# 17                                           Deloitte   entry_level
# 18                        English-El Enterprises, LLC   entry_level
# 19                                      Avila Trading   entry_level
# 20                                    The Soter Group   entry_level
# 21                                  Nathan Associates   entry_level
# 22                                            The KWO   entry_level
# 23            General Dynamics Information Technology   entry_level
# 24                                            Inspire   entry_level
# 25                                                IBM   entry_level
# 26                             City of Alexandria, VA   entry_level
# 27                                        IQlogg, Inc   entry_level
# 28                                   COLLABORAIT, INC   entry_level
# 29                              Global Strategy Group   entry_level
# ..                                                ...           ...
# 26                                  Cruise Automation  senior_level
# 27                                          LumenData  senior_level
# 28                                            Earnest  senior_level
# 29                              Williams-Sonoma, Inc.  senior_level
# 30                                       Zillow Group  senior_level
# 31                                         Salesforce  senior_level
# 32                               Resourznet Solutions  senior_level
# 33                                              Carta  senior_level
# 34                                  Walmart eCommerce  senior_level
# 35                              Williams-Sonoma, Inc.  senior_level
# 36                                             VMware  senior_level
# 37                                             Tanium  senior_level
# 38                             Tata Technologies Inc.  senior_level
# 39                                              Tesla  senior_level
# 40                                           Blue Owl  senior_level
# 41              Lawrence Berkeley National Laboratory  senior_level
# 42                              Williams-Sonoma, Inc.  senior_level
# 43                                           xiartech  senior_level
# 44                                            Discord  senior_level
# 45                                             Splunk  senior_level
# 46          University of California Office of the...  senior_level
# 47                                             Google  senior_level
# 48                                             Upwork  senior_level
# 49                               Peer Solutions Group  senior_level
# 50                            Chicago Global Services           NaN
# 51                                             Google           NaN
# 52                                       Factspan Inc           NaN
# 53                                   Juniper Networks           NaN
# 54                                        Abl Schools           NaN
# 55                                 Palo Alto Networks           NaN
#
#                                              Location  Salary  \
# 0                                      Washington, DC   60000
# 1            Washington, DC 20003 (Capitol Hill area)   60000
# 2                                      Washington, DC   60000
# 3                Washington, DC 20036 (Downtown area)   60000
# 4                                      Washington, DC   60000
# 5              Washington, DC 20201 (South West area)   60000
# 6                                        Woodlawn, MD   60000
# 7            Washington, DC 20005 (Logan Circle area)   60000
# 8                                      Washington, DC   60000
# 9                                      Washington, DC   60000
# 10                                     Washington, DC   60000
# 11                                     Washington, DC   60000
# 12                                     Washington, DC   60000
# 13                                     Washington, DC   60000
# 14            Arlington, VA 22201 (Lyon Village area)   60000
# 15                                     Alexandria, VA   60000
# 16           Washington, DC 20002 (Capitol Hill area)   60000
# 17            Arlington, VA 22201 (Lyon Village area)   60000
# 18                   Washington, DC 20001 (Shaw area)   60000
# 19                                     Alexandria, VA   60000
# 20                                         McLean, VA   60000
# 21                             Falls Church, VA 22046   60000
# 22                                     Washington, DC   60000
# 23                Arlington, VA 22203 (Bluemont area)   60000
# 24                                     Washington, DC   60000
# 25                                 Bethesda, MD 20814   60000
# 26                                     Washington, DC   60000
# 27           Washington, DC 20005 (Logan Circle area)   60000
# 28                                     Washington, DC   60000
# 29                                     Washington, DC   60000
# ..                                                ...     ...
# 26                                  San Francisco, CA  100000
# 27                                  San Francisco, CA  100000
# 28                                Sunnyvale, CA 94087  100000
# 29  San Francisco, CA 94111 (Financial District area)  100000
# 30                                Palo Alto, CA 94304  100000
# 31                                     Emeryville, CA  100000
# 32                                    Santa Clara, CA  100000
# 33                                        Fremont, CA  100000
# 34                                  San Francisco, CA  100000
# 35                         San Francisco Bay Area, CA  100000
# 36  San Francisco, CA 94111 (Financial District area)  100000
# 37                                      Sunnyvale, CA  100000
# 38                                  San Francisco, CA  100000
# 39     San Francisco, CA 94107 (South Of Market area)  100000
# 40    Oakland, CA 94607 (Acorn-Acorn Industrial area)  100000
# 41                                      Sunnyvale, CA  100000
# 42                                  Mountain View, CA  100000
# 43                                    Santa Clara, CA  100000
# 44                                  San Francisco, CA  100000
# 45                                  Mountain View, CA  100000
# 46                                  San Francisco, CA  100000
# 47                                Sunnyvale, CA 94089  100000
# 48                                  San Francisco, CA  100000
# 49                              Santa Clara, CA 95054  100000
# 50                                                NaN     NaN
# 51                                                NaN     NaN
# 52                                                NaN     NaN
# 53                                                NaN     NaN
# 54                                                NaN     NaN
# 55                                                NaN     NaN
#
#                                                 Title
# 0                                 Junior Data Analyst
# 1                                     Reports Analyst
# 2                                    Research Analyst
# 3                                        Data Analyst
# 4                Data Analyst - Experienced Associate
# 5                            Acquisition Data Analyst
# 6                           Data Analyst - Pay Band 3
# 7                      Research Analyst (Entry Level)
# 8                      Analyst, Strategy and Research
# 9                                     Program Analyst
# 10               Data Analyst II, Strategy & Planning
# 11                           OSSE: Management Analyst
# 12                                       Data Analyst
# 13                              Public Health Analyst
# 14                  Political Data Operations Analyst
# 15                           Data Analyst - Associate
# 16  Counterterrorism Intelligence Analyst Intern (...
# 17  Jr. Financial Data Analyst (Secret Clearance R...
# 18                               Data Analyst (USCIS)
# 19                                      Data Analayst
# 20                                       Data Analyst
# 21                                            Analyst
# 22                              Data Curation Analyst
# 23                                    Quality Analyst
# 24                                       Data Analyst
# 25                      Digital Change Junior Analyst
# 26                                 Management Analyst
# 27                                   SQL Data Analyst
# 28                                       Data Analyst
# 29                             Associate Data Analyst
# ..                                                ...
# 26                             Senior Product Analyst
# 27                            Senior Business Analyst
# 28              Senior Portfolio Quantitative Analyst
# 29             Sr. Data Analyst, Marketing Operations
# 30                        Senior Quantitative Analyst
# 31                             Senior Product Analyst
# 32                            Senior Business Analyst
# 33                             Senior Product Analyst
# 34                               Staff Data Scientist
# 35                                 Sr. Data Scientist
# 36                          Senior Operations Analyst
# 37                        Director, Analyst Relations
# 38                                  CAE Analyst (NVH)
# 39                                 Sr Analyst, BusOps
# 40                Senior Business Analyst - Insurance
# 41  Business Systems Analyst (Environment, Health,...
# 42                     Sr. Analyst, Loyalty Marketing
# 43  Senior Data Analyst With AI/ML with Python coding
# 44                                Senior Data Analyst
# 45                    Senior Sales Operations Analyst
# 46             Senior Investment Analyst, Real Assets
# 47   Systems Analyst, Lifecycle Technology Management
# 48                                  Principal Analyst
# 49                      Supply Chain Business Analyst
# 50                                  Sr Data Scientist
# 51                           Senior Financial Analyst
# 52                       Hiring Senior Data Scientist
# 53                  Corporate Strategy Senior Analyst
# 54                                 Sr. Data Scientist
# 55                     Sr. Marketing Planning Analyst
#
# [2515 rows x 5 columns]

# %%
#saving data
result_data_analyst.to_csv('result_Data_Analyst.csv', encoding='utf-8')
